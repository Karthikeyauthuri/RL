# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthikeyauthuri/RL/blob/main/RL_LAB2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

machines = ['A', 'B', 'C']
epsilon = 0.2
plays = 10

reward_pattern = {
    'A': [3, 4, 2, 5],
    'B': [6, 7, 5, 8],
    'C': [4, 3, 5, 4]
}

N = {'A': 0, 'B': 0, 'C': 0}
R = {'A': [], 'B': [], 'C': []}
Q = {'A': 0, 'B': 0, 'C': 0}

total_reward = 0

print("===== EPSILON-GREEDY MULTI-ARMED BANDIT =====")
print("Epsilon =", epsilon)
print("Total Plays =", plays)

for i in range(plays):

    r = random.random()

    if r < epsilon:
        machine = random.choice(machines)
        method = "Exploration"
    else:
        machine = max(Q, key=Q.get)
        method = "Exploitation"

    reward = reward_pattern[machine][N[machine] % 4]

    N[machine] += 1
    R[machine].append(reward)

    # Incremental average
    Q[machine] = Q[machine] + (reward - Q[machine]) / N[machine]

    total_reward += reward
    average_reward = total_reward / (i + 1)

    print("\n--------------------------------")
    print("Play Time:", i + 1)
    print("Random Value:", round(r, 3))
    print("Method:", method)
    print("Selected Machine:", machine)
    print("Reward:", reward)
    print("Machine Count N:", N[machine])
    print("Updated Q Average:", round(Q[machine], 2))
    print("Overall Average Reward:", round(average_reward, 2))

print("\n========== FINAL RESULTS ==========")

for machine in machines:
    print("\nMachine:", machine)
    print("Number of Plays N =", N[machine])
    print("Rewards =", R[machine])
    print("Average Q =", round(Q[machine], 2))

print("\n===================================")
print("Total Reward =", total_reward)
print("Overall Average Reward =", round(total_reward / plays, 2))

best = max(Q, key=Q.get)

print("Best Machine =", best)
print("Best Q Value =", round(Q[best], 2))
# Out:
# ===== EPSILON-GREEDY MULTI-ARMED BANDIT =====
# Epsilon = 0.2
# Total Plays = 10
#
# --------------------------------
# Play Time: 1
# Random Value: 0.693
# Method: Exploitation
# Selected Machine: A
# Reward: 3
# Machine Count N: 1
# Updated Q Average: 3.0
# Overall Average Reward: 3.0
#
# --------------------------------
# Play Time: 2
# Random Value: 0.012
# Method: Exploration
# Selected Machine: C
# Reward: 4
# Machine Count N: 1
# Updated Q Average: 4.0
# Overall Average Reward: 3.5
#
# --------------------------------
# Play Time: 3
# Random Value: 0.368
# Method: Exploitation
# Selected Machine: C
# Reward: 3
# Machine Count N: 2
# Updated Q Average: 3.5
# Overall Average Reward: 3.33
#
# --------------------------------
# Play Time: 4
# Random Value: 0.419
# Method: Exploitation
# Selected Machine: C
# Reward: 5
# Machine Count N: 3
# Updated Q Average: 4.0
# Overall Average Reward: 3.75
#
# --------------------------------
# Play Time: 5
# Random Value: 0.786
# ...
