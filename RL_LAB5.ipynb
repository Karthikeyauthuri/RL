# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthikeyauthuri/RL/blob/main/RL_LAB5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gymnasium as gym
env = gym.make("MountainCar-v0")
print("Environment created")
# Out:
# Environment created

# %%
state, info = env.reset()
print("Car position:", state[0])
print("Car velocity:", state[1])
# Out:
# Car position: -0.5226591
# Car velocity: 0.0

# %%
action = env.action_space
print(action)
# Out:
# Discrete(3)

# %%
action = env.action_space.sample()
if action == 0:
    print("Accelerate left direction")
if action == 1:
    print("No Accelerate")
if action == 2:
    print("Accelerate right direction")
next_state, reward, terminated, truncated, info = env.step(action)
print("Current state:", state)
print("Next state:", next_state)
print("Reward:", reward)
print("Terminated:", terminated)
print("Truncated:", truncated)
# Out:
# Accelerate left direction
# Current state: [-0.5226591  0.       ]
# Next state: [-0.52366614 -0.00100705]
# Reward: -1.0
# Terminated: False
# Truncated: False

# %%
current_state, info = env.reset()
print("-" * 40)
print("Current State Information: Reset Environment")
print("-" * 40)
print(f"Car Position: {current_state[0]}")
print(f"Car Velocity: {current_state[1]}")
print("-" * 40)
episodes = 20
total_reward = 0
for episode in range(episodes):
    action = env.action_space.sample()
    if action == 0:
        print("Accelerate left direction")
    if action == 1:
        print("No Accelerate")
    if action == 2:
        print("Accelerate right direction")
    next_state, reward, terminated, truncated, info = env.step(action)
    print(
        f"episode={episode} | next_state={next_state} | "
        f"current_state={current_state} | reward={reward} | "
        f"terminated={terminated}"
    )

    total_reward += reward

    if terminated or truncated:
        current_state, info = env.reset()
    else:
        current_state = next_state

print(f"Total reward={total_reward}")
print(f"Average reward={total_reward / (episodes + 1)}")
# Out:
# ----------------------------------------
# Current State Information: Reset Environment
# ----------------------------------------
# Car Position: -0.4494764506816864
# Car Velocity: 0.0
# ----------------------------------------
# No Accelerate
# episode=0 | next_state=[-0.4500278  -0.00055135] | current_state=[-0.44947645  0.        ] | reward=-1.0 | terminated=False
# Accelerate left direction
# episode=1 | next_state=[-0.45212644 -0.00209866] | current_state=[-0.4500278  -0.00055135] | reward=-1.0 | terminated=False
# No Accelerate
# episode=2 | next_state=[-0.45475706 -0.00263061] | current_state=[-0.45212644 -0.00209866] | reward=-1.0 | terminated=False
# Accelerate right direction
# episode=3 | next_state=[-0.45690033 -0.00214326] | current_state=[-0.45475706 -0.00263061] | reward=-1.0 | terminated=False
# No Accelerate
# episode=4 | next_state=[-0.4595405  -0.00264016] | current_state=[-0.45690033 -0.00214326] | reward=-1.0 | terminated=False
# Accelerate right direction
# episode=5 | next_state=[-0.46165812 -0.00211765] | current_state=[-0.4595405  -0.00264016] | reward=-1.0 | terminated=False
# Accelerate right direction
# episode=6 | next_state=[-0.46323767 -0.00157953] | current_state=[-0.46165812 -0.00211765] | reward=-1.0 | terminated=False
# No Accelerate
# episode=7 | next_state=[-0.46526742 -0.00202977] | current_state=[-0.46323767 -0.00157953] | reward=-1.0 | terminated=False
# Accelerate left direction
# episode=8 | next_state=[-0.46873245 -0.00346503] | current_state=[-0.46526742 -0.00202977] | reward=-1.0 | terminated=False
# Accelerate right direction
# episode=9 | next_state=[-0.47160712 -0.00287467] | current_state=[-0.46873245 -0.00346503] | reward=-1.0 | terminated=False
# Accelerate left direction
# episode=10 | next_state=[-0.47587016 -0.00426303] | current_state=[-0.47160712 -0.00287467] | reward=-1.0 | terminated=False
# Accelerate left direction
# episode=11 | next_state=[-0.48148993 -0.00561977] | current_state=[-0.47587016 -0.00426303] | reward=-1.0 | terminated=False
# No Accelerate
# episode=12 | next_state=[-0.48742467 -0.00593475] | current_state=[-0.48148993 -0.00561977] | reward=-1.0 | terminated=False
# Accelerate left direction
# episode=13 | next_state=[-0.4946302  -0.00720552] | current_state=[-0.48742467 -0.00593475] | reward=-1.0 | terminated=False
# No Accelerate
# episode=14 | next_state=[-0.5020527  -0.00742251] | current_state=[-0.4946302  -0.00720552] | reward=-1.0 | terminated=False
# No Accelerate
# episode=15 | next_state=[-0.5096367  -0.00758399] | current_state=[-0.5020527  -0.00742251] | reward=-1.0 | terminated=False
# Accelerate left direction
# episode=16 | next_state=[-0.5183254  -0.00868868] | current_state=[-0.5096367  -0.00758399] | reward=-1.0 | terminated=False
# Accelerate left direction
# episode=17 | next_state=[-0.52805364 -0.00972823] | current_state=[-0.5183254  -0.00868868] | reward=-1.0 | terminated=False
# No Accelerate
# episode=18 | next_state=[-0.53774846 -0.00969482] | current_state=[-0.52805364 -0.00972823] | reward=-1.0 | terminated=False
# Accelerate right direction
# episode=19 | next_state=[-0.5463372  -0.00858873] | current_state=[-0.53774846 -0.00969482] | reward=-1.0 | terminated=False
# Total reward=-20.0
# Average reward=-0.9523809523809523
